# %%
import pandas as pd

from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import StandardScaler

# %%
df_train = pd.read_csv("../data/train.csv", index_col="id")
df_test = pd.read_csv("../data/test.csv", index_col="id")

# %% [markdown]
# #### Enconde categorical data

# %%
def encode_categorical_data(dataframe):
    cut_type = {
    'Ideal': 5,
    'Premium': 4,
    'Very Good': 3,
    'Good': 2,
    'Fair': 1
    }
    
    color_type = {
    'D': 7,
    'E': 6,
    'F': 5,
    'G': 4,
    'H': 3,
    'I': 2,
    'J': 1
    }
    
    clarity_type = {
    'IF': 8,
    'VVS1': 7,
    'VVS2': 6,
    'VS1': 5,
    'VS2': 4,
    'SI1': 3,
    'SI2': 2,
    'I1': 1
    }    

    dataframe['cut'] = dataframe['cut'].map(cut_type)
    dataframe['color'] = dataframe['color'].map(color_type)
    dataframe['clarity'] = dataframe['clarity'].map(clarity_type)
    
    return None

# %%
encode_categorical_data(df_train)
encode_categorical_data(df_test)

# %% [markdown]
# #### Drop columns that don't provide information

# %%
corr_ = df_train.corr(method='pearson')
pd.DataFrame(corr_).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_05d37_row0_col0,#T_05d37_row1_col1,#T_05d37_row2_col2,#T_05d37_row3_col3,#T_05d37_row4_col4,#T_05d37_row5_col5,#T_05d37_row6_col6,#T_05d37_row7_col7,#T_05d37_row8_col8,#T_05d37_row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_05d37_row0_col1,#T_05d37_row6_col4{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_05d37_row0_col2,#T_05d37_row1_col5,#T_05d37_row3_col0,#T_05d37_row3_col6,#T_05d37_row3_col7,#T_05d37_row3_col8,#T_05d37_row3_col9,#T_05d37_row5_col1,#T_05d37_row5_col4,#T_05d37_row6_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_05d37_row0_col3{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_05d37_row0_col4,#T_05d37_row4_col7{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_05d37_row0_col5{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_05d37_row0_col6,#T_05d37_row6_col0{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_05d37_row0_col7,#T_05d37_row7_col0{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_05d37_row0_col8,#T_05d37_row7_col9,#T_05d37_row8_col0{
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }#T_05d37_row0_col9{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_05d37_row1_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_05d37_row1_col2,#T_05d37_row9_col1{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_05d37_row1_col3,#T_05d37_row9_col5{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_05d37_row1_col4{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_05d37_row1_col6,#T_05d37_row1_col7,#T_05d37_row4_col9{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_05d37_row1_col8{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_05d37_row1_col9{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_05d37_row2_col0{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_05d37_row2_col1{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_05d37_row2_col3{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_05d37_row2_col4,#T_05d37_row3_col5,#T_05d37_row4_col2{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_05d37_row2_col5,#T_05d37_row4_col0{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_05d37_row2_col6{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_05d37_row2_col7,#T_05d37_row2_col8{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_05d37_row2_col9{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_05d37_row3_col1,#T_05d37_row7_col5{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_05d37_row3_col2,#T_05d37_row5_col2,#T_05d37_row7_col4{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_05d37_row3_col4{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_05d37_row4_col1{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_05d37_row4_col3{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_05d37_row4_col5{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_05d37_row4_col6{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_05d37_row4_col8{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_05d37_row5_col0{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_05d37_row5_col3{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_05d37_row5_col6{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_05d37_row5_col7{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_05d37_row5_col8{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_05d37_row5_col9{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_05d37_row6_col1{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_05d37_row6_col2,#T_05d37_row7_col2,#T_05d37_row8_col2{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_05d37_row6_col5{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_05d37_row6_col7,#T_05d37_row7_col6{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_05d37_row6_col8,#T_05d37_row8_col6{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_05d37_row6_col9,#T_05d37_row9_col7{
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }#T_05d37_row7_col1{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_05d37_row7_col3,#T_05d37_row8_col3{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_05d37_row7_col8,#T_05d37_row8_col7,#T_05d37_row9_col6{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_05d37_row8_col1{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_05d37_row8_col4{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_05d37_row8_col5{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_05d37_row8_col9{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_05d37_row9_col0{
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }#T_05d37_row9_col2{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_05d37_row9_col3{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_05d37_row9_col4{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_05d37_row9_col8{
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }</style><table id="T_05d37_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >carat</th>        <th class="col_heading level0 col1" >cut</th>        <th class="col_heading level0 col2" >color</th>        <th class="col_heading level0 col3" >clarity</th>        <th class="col_heading level0 col4" >depth</th>        <th class="col_heading level0 col5" >table</th>        <th class="col_heading level0 col6" >x</th>        <th class="col_heading level0 col7" >y</th>        <th class="col_heading level0 col8" >z</th>        <th class="col_heading level0 col9" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_05d37_level0_row0" class="row_heading level0 row0" >carat</th>
#                         <td id="T_05d37_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_05d37_row0_col1" class="data row0 col1" >-0.136191</td>
#                         <td id="T_05d37_row0_col2" class="data row0 col2" >-0.291000</td>
#                         <td id="T_05d37_row0_col3" class="data row0 col3" >-0.354075</td>
#                         <td id="T_05d37_row0_col4" class="data row0 col4" >0.029877</td>
#                         <td id="T_05d37_row0_col5" class="data row0 col5" >0.182316</td>
#                         <td id="T_05d37_row0_col6" class="data row0 col6" >0.976032</td>
#                         <td id="T_05d37_row0_col7" class="data row0 col7" >0.968603</td>
#                         <td id="T_05d37_row0_col8" class="data row0 col8" >0.948812</td>

# %%
df_train.drop(['depth','table'], axis = 1, inplace = True) 
df_test.drop(['depth','table'], axis = 1, inplace = True)

# %% [markdown]
# #### Standarization of the data

# %%
def standarize_data(dataframe):
    scaler = StandardScaler()
    to_standarize = ['carat', 'cut', 'color', 'clarity', 'x', 'y', 'z']
    for attribute in to_standarize:
        dataframe[attribute] = scaler.fit_transform(dataframe[attribute].values.reshape(-1, 1))
    return None

# %%
standarize_data(df_train)
standarize_data(df_test)

# %% [markdown]
# #### Training the model and predicting

# %%
X = df_train.drop("price", axis=1)
y = df_train['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
model = RandomForestRegressor(n_estimators = 400,
                              max_depth = 80, 
                              min_samples_split = 8, 
                              min_samples_leaf = 3, 
                              bootstrap=True, 
                              n_jobs=-1)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=80, min_samples_leaf=3, min_samples_split=8,
#                       n_estimators=400, n_jobs=-1)

# %%
y_pred = model.predict(X_test)

# %%
print('RMSE - ', mean_squared_error(y_test, y_pred, squared=False))
# Out:
# RMSE -  0.08777272685773295

# %% [markdown]
# #### Generate file for kaggle submission

# %%
X = df_train.drop("price", axis=1)
y = df_train['price']

model = RandomForestRegressor(n_estimators = 400,
                              max_depth = 80, 
                              min_samples_split = 8, 
                              min_samples_leaf = 4, 
                              bootstrap=True, 
                              n_jobs=-1)

model.fit(X, y)
y_pred = model.predict(df_test)

# %%
df_submission = pd.DataFrame(y_pred, columns=["price"])
df_submission.reset_index(inplace=True)
df_submission.rename({"index":"id"}, axis=1, inplace=True)

# %%
df_submission.to_csv("../data/submission.csv", index=False)
